# %% [markdown]
# # Setup

# %%
# General libraries
import pandas as pd
import numpy as np
import warnings
from datetime import datetime
import gc
import os

# Plots
from matplotlib import pyplot as plt

# Plots
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Pd options
pd.set_option('display.max_columns', None)

# %%
# Suppress warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# Suppress the specific PerformanceWarning
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# Suppress SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# %%
# Get the current date and time
current_time = datetime.now()

# Format the date and time for the filename
formatted_date = current_time.strftime("%Y_%m_%d_%H_%M")

# Show
formatted_date
# Out:
# '2024_10_25_18_30'

# %% [markdown]
# # Directory

# %%
# Set cd to parent directory
os.chdir("/Users/ignasipascual/Documents/GitHub/LightGBM-Forecaster")
cwd = os.getcwd()
print("Current Working Directory:", cwd)
# Out:
# Current Working Directory: /Users/ignasipascual/Documents/GitHub/LightGBM-Forecaster

# %%
# Set source
source = 'local'

# Print files in directory
if source == 'gdrive':
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir('/content/drive/MyDrive/Forecasting')
    print("Listing files from Google Drive 'Forecasting' directory:")
else:
    print("Listing files from the current local directory:")

# List files in the specified directory
files = os.listdir()

# Print each file
for file in files:
    print(file)
# Out:
# Listing files from the current local directory:
# .DS_Store
# LICENSE
# requirements.txt
# utils
# docs
# README.md
# submissions
# .git
# data
# notebooks

# %% [markdown]
# # Assets

# %% [markdown]
# ## Import assets

# %%
# Import assets
from utils.auxiliar import *

# %% [markdown]
# # Load data

# %%
# Create the filename with the phase appended
file_name = f'Data/df_lightgbm_preds.csv'

# Read the CSV file
df_input = pd.read_csv(file_name)

# Show
df_input.head()
# Out:
#    client  warehouse  product    id_column        date  sales  price  \
# 0       1        235    13692  1/235/13692  2020-07-06    0.0    NaN
# 1       1        235     4290   1/235/4290  2020-07-06    0.0    NaN
# 2       1        235     5386   1/235/5386  2020-07-06    0.0    NaN
# 3       1        235     6153   1/235/6153  2020-07-06    0.0    NaN
# 4       1        235     7350   1/235/7350  2020-07-06    0.0    NaN
#
#    filled_sales  filled_price      cutoff sample  feature_client  \
# 0           0.0           NaN  2023-11-06  train               0
# 1           0.0           NaN  2023-11-06  train               0
# 2           0.0           NaN  2023-11-06  train               0
# 3           0.0           NaN  2023-11-06  train               0
# 4           0.0           NaN  2023-11-06  train               0
#
#    feature_warehouse  feature_product  feature_id_column  feature_periods  \
# 0                 10              658                 62              0.0
# 1                 10             1298                 93              0.0
# 2                 10             1485                 99              0.0
# 3                 10             1630                109              0.0
# 4                 10             1893                113              0.0
#
#    feature_periods_expanding  feature_periods_sqrt  feature_year  \
# 0                        0.0                   0.0          2020
# 1                        0.0                   0.0          2020
# 2                        0.0                   0.0          2020
# 3                        0.0                   0.0          2020
# 4                        0.0                   0.0          2020
#
#    feature_quarter  feature_month  feature_week  \
# 0                3              7            28
# 1                3              7            28
# 2                3              7            28
# 3                3              7            28
# 4                3              7            28
#
#    feature_weeks_until_next_end_of_quarter  feature_weeks_until_end_of_year  \
# 0                                       12                               25
# 1                                       12                               25
# 2                                       12                               25
# 3                                       12                               25
# 4                                       12                               25
#
#    feature_months_until_next_end_of_quarter  feature_months_until_end_of_year  \
# 0                                         2                                 5
# 1                                         2                                 5
# 2                                         2                                 5
# 3                                         2                                 5
# 4                                         2                                 5
#
#    filled_sales_ma_4  filled_sales_ma_13  filled_price_ma_4  \
# 0                0.0                 0.0                NaN
# 1                0.0                 0.0                NaN
# 2                0.0                 0.0                NaN
# 3                0.0                 0.0                NaN
# 4                0.0                 0.0                NaN
#
#    filled_price_ma_13  filled_sales_min_13  filled_sales_max_13  \
# 0                 NaN                  0.0                  0.0
# 1                 NaN                  0.0                  0.0
# 2                 NaN                  0.0                  0.0
# 3                 NaN                  0.0                  0.0
# 4                 NaN                  0.0                  0.0
#
#    filled_price_min_13  filled_price_max_13  feature_filled_sales_lag_13  \
# 0                  NaN                  NaN                          NaN
# 1                  NaN                  NaN                          NaN
# 2                  NaN                  NaN                          NaN
# 3                  NaN                  NaN                          NaN
# 4                  NaN                  NaN                          NaN
#
#    feature_filled_sales_lag_52  feature_filled_price_lag_13  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    feature_filled_price_lag_52  feature_filled_sales_ma_4_lag_13  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 3                          NaN                               NaN
# 4                          NaN                               NaN
#
#    feature_filled_sales_ma_4_lag_52  feature_filled_price_ma_4_lag_13  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    feature_filled_price_ma_4_lag_52  feature_filled_sales_ma_13_lag_13  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#    feature_filled_sales_ma_13_lag_52  feature_filled_price_ma_13_lag_13  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#    feature_filled_price_ma_13_lag_52  feature_filled_sales_min_13_lag_13  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#    feature_filled_sales_min_13_lag_52  feature_filled_sales_max_13_lag_13  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    feature_filled_sales_max_13_lag_52  feature_filled_sales_cov  \
# 0                                 NaN                      7.57
# 1                                 NaN                      9.30
# 2                                 NaN                      7.57
# 3                                 NaN                      9.30
# 4                                 NaN                     13.19
#
#    feature_distinct_product_client  feature_distinct_product_warehouse  \
# 0                                1                                   3
# 1                                1                                   2
# 2                                1                                   1
# 3                                1                                   1
# 4                                1                                   2
#
#    feature_distinct_product_cutoff  feature_filled_sales_cluster  \
# 0                                3                             1
# 1                                3                             1
# 2                                3                             1
# 3                                3                             1
# 4                                3                             1
#
#    feature_filled_price_cluster  feature_periods_history_cluster  \
# 0                             1                                1
# 1                             1                                1
# 2                             1                                1
# 3                             1                                1
# 4                             1                                1
#
#    feature_intermittence_filled_sales_cluster  train_weight  \
# 0                                           8           0.0
# 1                                           8           0.0
# 2                                           8           0.0
# 3                                           9           0.0
# 4                                           8           0.0
#
#    feature_baseline_filled_sales_ma_13  feature_baseline_filled_price_ma_13  \
# 0                                  0.0                                  NaN
# 1                                  0.0                                  NaN
# 2                                  0.0                                  NaN
# 3                                  0.0                                  NaN
# 4                                  0.0                                  NaN
#
#    baseline_filled_sales_ma_13  baseline_filled_price_ma_13  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    baseline_filled_price_lgbm  feature_baseline_filled_price_lgbm  \
# 0                         NaN                                 NaN
# 1                         NaN                                 NaN
# 2                         NaN                                 NaN
# 3                         NaN                                 NaN
# 4                         NaN                                 NaN
#
#    training_group  guardrail  prediction
# 0               1      False         NaN
# 1               1      False         NaN
# 2               1      False         NaN
# 3               1      False         NaN
# 4               1      False         NaN

# %% [markdown]
# # Prepare results

# %%
# Convert the 'date' column to datetime
df_input['date'] = pd.to_datetime(df_input['date'])

# Find the maximum date in the dataset
max_date = df_input['date'].max()

# Define the cutoff date (6 weeks before the max date)
cutoff_date = max_date - pd.Timedelta(weeks=6)

# Filter for sales data within the last 6 weeks
last_6_weeks_data = df_input[df_input['date'] > cutoff_date]

# Group by 'id_column' and calculate the sum of sales
sales_summary = last_6_weeks_data.groupby('id_column')['sales'].sum().reset_index()

# Identify inactive ids (sum of sales is 0 or lower)
inactive_ids = sales_summary[sales_summary['sales'] <= 0]['id_column']

# Filter out inactive groups from the original dataset
df_filtered = df_input[~df_input['id_column'].isin(inactive_ids)]

# Show
df_filtered.head()
# Out:
#    client  warehouse  product    id_column       date  sales  price  \
# 0       1        235    13692  1/235/13692 2020-07-06    0.0    NaN
# 1       1        235     4290   1/235/4290 2020-07-06    0.0    NaN
# 2       1        235     5386   1/235/5386 2020-07-06    0.0    NaN
# 3       1        235     6153   1/235/6153 2020-07-06    0.0    NaN
# 4       1        235     7350   1/235/7350 2020-07-06    0.0    NaN
#
#    filled_sales  filled_price      cutoff sample  feature_client  \
# 0           0.0           NaN  2023-11-06  train               0
# 1           0.0           NaN  2023-11-06  train               0
# 2           0.0           NaN  2023-11-06  train               0
# 3           0.0           NaN  2023-11-06  train               0
# 4           0.0           NaN  2023-11-06  train               0
#
#    feature_warehouse  feature_product  feature_id_column  feature_periods  \
# 0                 10              658                 62              0.0
# 1                 10             1298                 93              0.0
# 2                 10             1485                 99              0.0
# 3                 10             1630                109              0.0
# 4                 10             1893                113              0.0
#
#    feature_periods_expanding  feature_periods_sqrt  feature_year  \
# 0                        0.0                   0.0          2020
# 1                        0.0                   0.0          2020
# 2                        0.0                   0.0          2020
# 3                        0.0                   0.0          2020
# 4                        0.0                   0.0          2020
#
#    feature_quarter  feature_month  feature_week  \
# 0                3              7            28
# 1                3              7            28
# 2                3              7            28
# 3                3              7            28
# 4                3              7            28
#
#    feature_weeks_until_next_end_of_quarter  feature_weeks_until_end_of_year  \
# 0                                       12                               25
# 1                                       12                               25
# 2                                       12                               25
# 3                                       12                               25
# 4                                       12                               25
#
#    feature_months_until_next_end_of_quarter  feature_months_until_end_of_year  \
# 0                                         2                                 5
# 1                                         2                                 5
# 2                                         2                                 5
# 3                                         2                                 5
# 4                                         2                                 5
#
#    filled_sales_ma_4  filled_sales_ma_13  filled_price_ma_4  \
# 0                0.0                 0.0                NaN
# 1                0.0                 0.0                NaN
# 2                0.0                 0.0                NaN
# 3                0.0                 0.0                NaN
# 4                0.0                 0.0                NaN
#
#    filled_price_ma_13  filled_sales_min_13  filled_sales_max_13  \
# 0                 NaN                  0.0                  0.0
# 1                 NaN                  0.0                  0.0
# 2                 NaN                  0.0                  0.0
# 3                 NaN                  0.0                  0.0
# 4                 NaN                  0.0                  0.0
#
#    filled_price_min_13  filled_price_max_13  feature_filled_sales_lag_13  \
# 0                  NaN                  NaN                          NaN
# 1                  NaN                  NaN                          NaN
# 2                  NaN                  NaN                          NaN
# 3                  NaN                  NaN                          NaN
# 4                  NaN                  NaN                          NaN
#
#    feature_filled_sales_lag_52  feature_filled_price_lag_13  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    feature_filled_price_lag_52  feature_filled_sales_ma_4_lag_13  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 3                          NaN                               NaN
# 4                          NaN                               NaN
#
#    feature_filled_sales_ma_4_lag_52  feature_filled_price_ma_4_lag_13  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    feature_filled_price_ma_4_lag_52  feature_filled_sales_ma_13_lag_13  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#    feature_filled_sales_ma_13_lag_52  feature_filled_price_ma_13_lag_13  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#    feature_filled_price_ma_13_lag_52  feature_filled_sales_min_13_lag_13  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#    feature_filled_sales_min_13_lag_52  feature_filled_sales_max_13_lag_13  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    feature_filled_sales_max_13_lag_52  feature_filled_sales_cov  \
# 0                                 NaN                      7.57
# 1                                 NaN                      9.30
# 2                                 NaN                      7.57
# 3                                 NaN                      9.30
# 4                                 NaN                     13.19
#
#    feature_distinct_product_client  feature_distinct_product_warehouse  \
# 0                                1                                   3
# 1                                1                                   2
# 2                                1                                   1
# 3                                1                                   1
# 4                                1                                   2
#
#    feature_distinct_product_cutoff  feature_filled_sales_cluster  \
# 0                                3                             1
# 1                                3                             1
# 2                                3                             1
# 3                                3                             1
# 4                                3                             1
#
#    feature_filled_price_cluster  feature_periods_history_cluster  \
# 0                             1                                1
# 1                             1                                1
# 2                             1                                1
# 3                             1                                1
# 4                             1                                1
#
#    feature_intermittence_filled_sales_cluster  train_weight  \
# 0                                           8           0.0
# 1                                           8           0.0
# 2                                           8           0.0
# 3                                           9           0.0
# 4                                           8           0.0
#
#    feature_baseline_filled_sales_ma_13  feature_baseline_filled_price_ma_13  \
# 0                                  0.0                                  NaN
# 1                                  0.0                                  NaN
# 2                                  0.0                                  NaN
# 3                                  0.0                                  NaN
# 4                                  0.0                                  NaN
#
#    baseline_filled_sales_ma_13  baseline_filled_price_ma_13  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    baseline_filled_price_lgbm  feature_baseline_filled_price_lgbm  \
# 0                         NaN                                 NaN
# 1                         NaN                                 NaN
# 2                         NaN                                 NaN
# 3                         NaN                                 NaN
# 4                         NaN                                 NaN
#
#    training_group  guardrail  prediction
# 0               1      False         NaN
# 1               1      False         NaN
# 2               1      False         NaN
# 3               1      False         NaN
# 4               1      False         NaN

# %%
# Calculate stats about the inactive ids
total_ids = df_input['id_column'].nunique()
inactive_count = inactive_ids.nunique()
inactive_percentage = (inactive_count / total_ids) * 100 if total_ids > 0 else 0

# Show stats
print(f"Total number of unique ids: {total_ids}")
print(f"Number of inactive ids: {inactive_count}")
print(f"Percentage of inactive ids: {inactive_percentage:.2f}%")
# Out:
# Total number of unique ids: 2936
# Number of inactive ids: 0
# Percentage of inactive ids: 0.00%

# %%
# Coerce negative values in the 'baseline_filled_sales_ma_13' column to 0
df_filtered['baseline_filled_sales_ma_13'] = df_filtered['baseline_filled_sales_ma_13'].clip(lower=0)

# Coerce negative values in the 'prediction' column to 0
df_filtered['prediction'] = df_filtered['prediction'].clip(lower=0)

# %% [markdown]
# # Prepare submission

# %%
# Parameters
value_to_pivot = 'prediction'

# Prepare submission using the prediction values
submission_df = prepare_submission(df_filtered, value_to_pivot)

# Rename columns
submission_df = submission_df.rename(columns={
        'client': 'Client',
        'warehouse': 'Warehouse',
        'product': 'Product'
})

# Show
submission_df.head()
# Out:
# Latest cutoff date selected: 2024-01-01 00:00:00
#    Client  Warehouse  Product  2024-01-08  2024-01-15  2024-01-22  2024-01-29  \
# 0       1         36     6101    0.227088    0.235581    0.250776    0.251753
# 1       1         36     6795    0.076415    0.092745    0.092914    0.101643
# 2       1         36    11992    0.590062    0.767407    0.747473    0.618525
# 3       1         40     7628    0.397730    0.395663    0.330820    0.378627
# 4       1         46       81    0.212294    0.116978    0.104560    0.091745
#
#    2024-02-05  2024-02-12  2024-02-19  2024-02-26  2024-03-04  2024-03-11  \
# 0    0.257796    0.254420    0.273823    0.268263    0.435663    0.485721
# 1    0.099577    0.122933    0.142702    0.126092    0.157048    0.163699
# 2    0.690205    0.600250    0.632554    0.567059    0.573448    0.640449
# 3    0.394383    0.407186    0.367243    0.377780    0.438401    0.400095
# 4    0.094041    0.096690    0.099149    0.098223    0.100013    0.103771
#
#    2024-03-18  2024-03-25  2024-04-01
# 0    0.473331    0.505311    0.497690
# 1    0.137453    0.120776    0.119067
# 2    0.584810    0.382438    0.504012
# 3    0.257108    0.188163    0.284021
# 4    0.149791    0.104139    0.078704

# %% [markdown]
# # Final checks

# %%
# Print the columns of the resulting DataFrame
print("Columns in the submission DataFrame:")
print(submission_df.columns.tolist())
# Out:
# Columns in the submission DataFrame:
# ['Client', 'Warehouse', 'Product', '2024-01-08', '2024-01-15', '2024-01-22', '2024-01-29', '2024-02-05', '2024-02-12', '2024-02-19', '2024-02-26', '2024-03-04', '2024-03-11', '2024-03-18', '2024-03-25', '2024-04-01']

# %%
# Print the number of columns that are not keys
non_key_columns_count = submission_df.shape[1] - 3
print(f"Number of predictions: {non_key_columns_count}")
# Out:
# Number of predictions: 13

# %% [markdown]
# # Save output

# %%
# Define the model name
final_model = "ml"

# %%
# Create the filename with the phase appended
filename = f'Submissions/submission_{final_model}_{formatted_date}.csv'

# Save the output dataframe to the CSV file
submission_df.to_csv(filename, index=False)
