# %% [markdown]
# # Setup

# %%
# General libraries
import pandas as pd
import numpy as np
import warnings
import lightgbm
import gc
import os

# Plots
from matplotlib import pyplot as plt

# Sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import TimeSeriesSplit
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingRandomSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import mutual_info_regression

# Forecaster
from lightgbm import LGBMRegressor

# Multiprocessing
from concurrent.futures import ProcessPoolExecutor
import multiprocessing
from functools import partial

# Plots
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from IPython import display
from time import sleep
from math import ceil

# Cuda
import torch

# Pd options
pd.set_option('display.max_columns', None)
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
# Suppress warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# Suppress the specific PerformanceWarning
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# Suppress SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# %%
# Get the number of available CPUs
num_cpus = os.cpu_count()

# Show
print(num_cpus)
# Out:
# 8

# %%
# Check if CUDA is available
if torch.cuda.is_available():
    print("CUDA is available. Using GPU.")
else:
    print("CUDA is not available. Using CPU.")
# Out:
# CUDA is not available. Using CPU.

# %% [markdown]
# # Directory

# %%
# Set cd to parent directory
os.chdir("/Users/ignasipascual/Documents/GitHub/LightGBM-Forecaster")
cwd = os.getcwd()
print("Current Working Directory:", cwd)

# %%
# Set source
source = 'gdrive'

# Print files in directory
if source == 'gdrive':
    # Use directory from gdrive
    from google.colab import drive
    drive.mount('/content/drive')
    os.chdir('/content/drive/MyDrive/Forecasting')
    print("Listing files from Google Drive 'Forecasting' directory:")
    # Drivers for cuda
    # !mkdir -p /etc/OpenCL/vendors && echo "libnvidia-opencl.so.1" > /etc/OpenCL/vendors/nvidia.icd
    # Google colab options
    # Google
    from google.colab import output
    output.no_vertical_scroll()
else:
    print("Listing files from the current local directory:")

# List files in the specified directory
files = os.listdir()

# Print each file
for file in files:
    print(file)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Listing files from Google Drive 'Forecasting' directory:
# Data
# Other
# Data_Visualization.ipynb
# LSTM.ipynb
# lightning_logs
# SKforecast.ipynb
# Nitxtla.ipynb
# Submissions
# Submission.ipynb
# Data_Preparation.ipynb
# Ligth_GBM.ipynb

# %% [markdown]
# # Assets

# %% [markdown]
# ## Import assets

# %%
# Import assets
from utils.data_preparation import DataPreparation
from utils.feature_engineering import FeatureEngineering
from utils.create_baselines import CreateBaselines
from utils.forecaster import Forecaster
from utils.evaluator import Evaluator
from utils.auxiliar import *

# %% [markdown]
# # Load data

# %%
# Load data for all phases
df_prices_0 = pd.read_csv('Data/Phase 0 - Price.csv')
df_sales_0 = pd.read_csv('Data/Phase 0 - Sales.csv')
df_prices_1 = pd.read_csv('Data/Phase 1 - Price.csv')
df_sales_1 = pd.read_csv('Data/Phase 1 - Sales.csv')

# Perform a left join on 'Client', 'Warehouse', and 'Product' for prices and sales
df_prices = pd.merge(df_prices_0, df_prices_1, on=['Client', 'Warehouse', 'Product'], how='left')
df_sales = pd.merge(df_sales_0, df_sales_1, on=['Client', 'Warehouse', 'Product'], how='left')
# Out:
#    client  warehouse  product    id_column        date  sales  price  \
# 0       1        235    11931  1/235/11931  2020-07-06    0.0    NaN
# 1       1        235     2650   1/235/2650  2020-07-06    0.0    NaN
# 2       1        235     5386   1/235/5386  2020-07-06    0.0    NaN
# 3       1        235     5731   1/235/5731  2020-07-06    0.0    NaN
# 4       1        235     8231   1/235/8231  2020-07-06    0.0    NaN
#
#    filled_sales  filled_price      cutoff sample  feature_client  \
# 0           0.0           NaN  2023-11-06  train               0
# 1           0.0           NaN  2023-11-06  train               0
# 2           0.0           NaN  2023-11-06  train               0
# 3           0.0           NaN  2023-11-06  train               0
# 4           0.0           NaN  2023-11-06  train               0
#
#    feature_warehouse  feature_product  feature_id_column  feature_periods  \
# 0                 10              337                 44              0.0
# 1                 10              999                 77              0.0
# 2                 10             1485                 99              0.0
# 3                 10             1547                104              0.0
# 4                 10             2059                119              0.0
#
#    feature_periods_expanding  feature_periods_sqrt  feature_year  \
# 0                        0.0                   0.0          2020
# 1                        0.0                   0.0          2020
# 2                        0.0                   0.0          2020
# 3                        0.0                   0.0          2020
# 4                        0.0                   0.0          2020
#
#    feature_quarter  feature_month  feature_week  \
# 0                3              7            28
# 1                3              7            28
# 2                3              7            28
# 3                3              7            28
# 4                3              7            28
#
#    feature_weeks_until_next_end_of_quarter  feature_weeks_until_end_of_year  \
# 0                                       12                               25
# 1                                       12                               25
# 2                                       12                               25
# 3                                       12                               25
# 4                                       12                               25
#
#    feature_months_until_next_end_of_quarter  feature_months_until_end_of_year  \
# 0                                         2                                 5
# 1                                         2                                 5
# 2                                         2                                 5
# 3                                         2                                 5
# 4                                         2                                 5
#
#    filled_sales_ma_4  filled_sales_ma_13  filled_price_ma_4  \
# 0                0.0                 0.0                NaN
# 1                0.0                 0.0                NaN
# 2                0.0                 0.0                NaN
# 3                0.0                 0.0                NaN
# 4                0.0                 0.0                NaN
#
#    filled_price_ma_13  filled_sales_min_13  filled_sales_max_13  \
# 0                 NaN                  0.0                  0.0
# 1                 NaN                  0.0                  0.0
# 2                 NaN                  0.0                  0.0
# 3                 NaN                  0.0                  0.0
# 4                 NaN                  0.0                  0.0
#
#    filled_price_min_13  filled_price_max_13  feature_filled_sales_lag_13  \
# 0                  NaN                  NaN                          NaN
# 1                  NaN                  NaN                          NaN
# 2                  NaN                  NaN                          NaN
# 3                  NaN                  NaN                          NaN
# 4                  NaN                  NaN                          NaN
#
#    feature_filled_sales_lag_52  feature_filled_price_lag_13  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    feature_filled_price_lag_52  feature_filled_sales_ma_4_lag_13  \
# 0                          NaN                               NaN
# 1                          NaN                               NaN
# 2                          NaN                               NaN
# 3                          NaN                               NaN
# 4                          NaN                               NaN
#
#    feature_filled_sales_ma_4_lag_52  feature_filled_price_ma_4_lag_13  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    feature_filled_price_ma_4_lag_52  feature_filled_sales_ma_13_lag_13  \
# 0                               NaN                                NaN
# 1                               NaN                                NaN
# 2                               NaN                                NaN
# 3                               NaN                                NaN
# 4                               NaN                                NaN
#
#    feature_filled_sales_ma_13_lag_52  feature_filled_price_ma_13_lag_13  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
#
#    feature_filled_price_ma_13_lag_52  feature_filled_sales_min_13_lag_13  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#    feature_filled_sales_min_13_lag_52  feature_filled_sales_max_13_lag_13  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    feature_filled_sales_max_13_lag_52  feature_filled_sales_cov  \
# 0                                 NaN                      5.31
# 1                                 NaN                      4.97
# 2                                 NaN                      7.57
# 3                                 NaN                      5.83
# 4                                 NaN                      7.57
#
#    feature_distinct_product_client  feature_distinct_product_warehouse  \
# 0                                1                                   1
# 1                                1                                   2
# 2                                1                                   1
# 3                                1                                   2
# 4                                1                                   1
#
#    feature_distinct_product_cutoff  feature_filled_sales_cluster  \
# 0                                3                             3
# 1                                3                             5
# 2                                3                             2
# 3                                3                             3
# 4                                3                             2
#
#    feature_filled_price_cluster  feature_periods_history_cluster  \
# 0                             1                                1
# 1                             1                                1
# 2                             1                                1
# 3                             1                                1
# 4                             1                                1
#
#    feature_intermittence_filled_sales_cluster  train_weight  \
# 0                                           9           0.0
# 1                                          12           0.0
# 2                                          12           0.0
# 3                                          10           0.0
# 4                                          10           0.0
#
#    feature_baseline_filled_sales_ma_13  feature_baseline_filled_price_ma_13  \
# 0                                  0.0                                  NaN
# 1                                  0.0                                  NaN
# 2                                  0.0                                  NaN
# 3                                  0.0                                  NaN
# 4                                  0.0                                  NaN
#
#    baseline_filled_sales_ma_13  baseline_filled_price_ma_13  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    baseline_filled_price_lgbm  feature_baseline_filled_price_lgbm
# 0                         NaN                                 NaN
# 1                         NaN                                 NaN
# 2                         NaN                                 NaN
# 3                         NaN                                 NaN
# 4                         NaN                                 NaN

# %%
# Unpivot dataset
df_prices_unpiv = unpivot_data(df_prices, id_vars=['Client', 'Warehouse', 'Product'], var_name='Date', value_name='Price')
df_sales_unpiv = unpivot_data(df_sales, id_vars=['Client', 'Warehouse', 'Product'], var_name='Date', value_name='Sales')

# Merge the two dataframes
df_input = df_sales_unpiv.merge(df_prices_unpiv, how = 'left', on = ['Client', 'Warehouse', 'Product', 'Date'])

# Round to 2 decimals
df_input['Sales'] = df_input['Sales'].round(2)
df_input['Price'] = df_input['Price'].round(2)

# Display the unpivoted dataframe
df_input.head()

# %% [markdown]
# ## Filter scope

# %%
# Filter for one client
clients = range(1, 7)

# Apply filter
df_input = df_input[df_input['Client'].isin(clients)]

# Show
df_input.head()

# %% [markdown]
# ## Formatting

# %%
# Convert all column names to lowercase
df_input.columns = df_input.columns.str.lower()

# Date format
df_input['date'] = pd.to_datetime(df_input['date'])

# Convert each specified column to string
character_cols = ['client', 'warehouse', 'product']
for col in character_cols:
    df_input[col] = df_input[col].astype(str)

# Convert signal columns to numeric, coercing errors to NaN
signal_cols = ['sales', 'price']
for col in signal_cols:
    df_input[col] = pd.to_numeric(df_input[col], errors='coerce')

# Create id column
df_input['id_column'] = df_input['client'] + '/' + df_input['warehouse'] + '/' + df_input['product']

# Select the specified columns
df_input = df_input[['client', 'warehouse', 'product', 'id_column', 'date', 'sales', 'price']]

# Sort by 'id_column' and 'date' in ascending order
df_input = df_input.sort_values(by=['id_column', 'date'])

# Show
df_input.head()

# %% [markdown]
# ## Statistics

# %%
# Print the number of rows and columns
print(f"Number of columns in df_input: {df_input.shape[1]}")
print(f"Number of rows in df_input: {df_input.shape[0]}")

# Print the number of distinct values for each specified column
print(f"Number of distinct clients: {df_input['client'].nunique()}")
print(f"Number of distinct warehouses: {df_input['warehouse'].nunique()}")
print(f"Number of distinct products: {df_input['product'].nunique()}")
print(f"Number of distinct id_column values: {df_input['id_column'].nunique()}")
# Out:
# Duplicate column names: []

# %%
# Calculate the percentage of NA values in the entire DataFrame
total_rows = len(df_input)
total_na = df_input.isna().sum().sum()
percent_na_total = (total_na / (total_rows * df_input.shape[1])) * 100
print(f"Overall percentage of NA values: {percent_na_total:.2f}%")

# %% [markdown]
# # Data Preparation

# %%
# Init class
data_preparation = DataPreparation()

# %%
# Run data preparation
df_data_prepared = data_preparer.run_data_preparation(
    df=df_input,
    group_cols=['client', 'warehouse', 'product'],
    date_col='date',
    target='sales',
    horizon=13,
    freq='W',
    complete_dataframe=False,
    smoothing=True,
    ma_window_size=13,
    n_cutoffs=5
)

# Show
df_data_prepared.head()

# %% [markdown]
# # Feature Engineering

# %%
# Parameters for feature engineering
group_columns = ['client', 'warehouse', 'product', 'cutoff']
date_column = 'date'
target = 'filled_sales'
horizon = 13
freq = 'W'

# Clusters
n_groups = 10

# %%
# Run feature engineering
df_with_features = feature_engineer.run_feature_engineering(
    df=df_data_prepared,
    group_cols=['client', 'warehouse', 'product', 'cutoff'],
    date_col='date',
    target='filled_sales',
    horizon=13,
    freq='W',
    window_sizes=(4, 13),
    lags=(4, 13),
    n_clusters=15,
    train_weight_type='linear'
)

# %% [markdown]
# # Create Baselines

# %%
# Parameters for baseline creation
group_columns = ['client', 'warehouse', 'product', 'cutoff']
date_column = 'date'

# %%
# Prepare class
create_baselines = CreateBaselines()

# %%
# Parameters
signal_columns = ['filled_sales_ma_13', 'filled_price_ma_13']
window_size = 13

# Call the function
df_with_ma_baseline = create_baselines.create_ma_baseline(df_with_features, group_columns, date_column, signal_columns, window_size)

# Show
df_with_ma_baseline.head()

# %%
# Parameters
group_columns = ['feature_filled_price_cluster', 'cutoff']
signal_columns = ['filled_price']
feature_columns = ['feature_client', 'feature_warehouse', 'feature_product', 'feature_periods', 'feature_year', 'feature_month', 'feature_week']

# Call the function
df_backtesting = create_baselines.create_lgbm_baseline(df_with_ma_baseline, group_columns, date_column, signal_columns, feature_columns)

# Show
df_backtesting.head()

# %% [markdown]
# # Forecasting model

# %% [markdown]
# ## Features

# %%
# Automatically find all feature columns containing 'feature' in their names
features = [col for col in df_backtesting.columns if "feature" in col]

# Create default trainining group
df_backtesting['training_group'] = 1

# Show
features
# Out:
# ['feature_client',
#  'feature_warehouse',
#  'feature_product',
#  'feature_id_column',
#  'feature_periods',
#  'feature_periods_expanding',
#  'feature_periods_sqrt',
#  'feature_year',
#  'feature_quarter',
#  'feature_month',
#  'feature_week',
#  'feature_weeks_until_next_end_of_quarter',
#  'feature_weeks_until_end_of_year',
#  'feature_months_until_next_end_of_quarter',
#  'feature_months_until_end_of_year',
#  'feature_filled_sales_lag_13',
#  'feature_filled_sales_lag_52',
#  'feature_filled_price_lag_13',
#  'feature_filled_price_lag_52',
#  'feature_filled_sales_ma_4_lag_13',
#  'feature_filled_sales_ma_4_lag_52',
#  'feature_filled_price_ma_4_lag_13',
#  'feature_filled_price_ma_4_lag_52',
#  'feature_filled_sales_ma_13_lag_13',
#  'feature_filled_sales_ma_13_lag_52',
#  'feature_filled_price_ma_13_lag_13',
#  'feature_filled_price_ma_13_lag_52',
#  'feature_filled_sales_min_13_lag_13',
#  'feature_filled_sales_min_13_lag_52',
#  'feature_filled_sales_max_13_lag_13',
#  'feature_filled_sales_max_13_lag_52',
#  'feature_filled_sales_cov',
#  'feature_distinct_product_client',
#  'feature_distinct_product_warehouse',
#  'feature_distinct_product_cutoff',
#  'feature_filled_sales_cluster',
#  'feature_filled_price_cluster',
#  'feature_periods_history_cluster',
#  'feature_intermittence_filled_sales_cluster',
#  'feature_baseline_filled_sales_ma_13',
#  'feature_baseline_filled_price_ma_13',
#  'feature_baseline_filled_price_lgbm']

# %%
# Number of features
print("Number of features:", len(features))
# Out:
# Number of features: 42

# %% [markdown]
# ## Hyperparameters

# %%
# Define the default LightGBM hyperparameters
default_lgb_hyperparams = {
    'objective': 'regression',
    'boosting_type': 'gbdt',
    'metric': 'rmse',
    'num_iterations': 2500,
    'learning_rate': 0.01,
    'num_leaves': 31,
    'max_depth': -1,
    'verbosity': -1,
    'seed': 42
}

# Define the LightGBM parameters
hyperparameter_grid = {
    'objective': ['regression'],
    'boosting_type': ['gbdt'],
    'num_iterations': [1000, 1500, 2000, 2500],
    'learning_rate': [0.01, 0.025, 0.05, 0.10],
    'num_leaves': [16, 32, 48],
    'max_depth': [4, 8, 12]
}

# Calculate the number of combinations directly
num_combinations = len(hyperparameter_grid['objective']) * \
                   len(hyperparameter_grid['boosting_type']) * \
                   len(hyperparameter_grid['num_iterations']) * \
                   len(hyperparameter_grid['learning_rate']) * \
                   len(hyperparameter_grid['num_leaves']) * \
                   len(hyperparameter_grid['max_depth'])

# Print the result
print("Number of combinations for Grid Search:", num_combinations)
# Out:
# Number of combinations for Grid Search: 144

# %% [markdown]
# ## Configuration

# %%
# Parameters
group_cols = ['client', 'warehouse', 'product']
training_group = 'feature_filled_sales_cluster'
target_col = 'filled_sales'
tune_hyperparameters = False
search_method = 'random'
param_distributions = hyperparameter_grid
scoring_metric = 'neg_mean_squared_log_error'
best_features = False
n_best_features = 20
use_weights = True

# Outliers
remove_outliers = True
outlier_column = 'filled_sales'
lower_quantile = 0.01
upper_quantile = 0.99

# Guardrail
baseline_col = 'baseline_filled_sales_ma_13'
use_guardrail = True
guardrail_limit = 2.5

# Parallel
use_parallel = False
num_cpus = 5

# %% [markdown]
# ## Run Predictor

# %%
# %%time
# Initialize the Forecaster class with df_input
forecaster = Forecaster(df_backtesting)

# Call the function
df_with_preds = forecaster.run_backtesting(
    group_cols,
    features,
    default_lgb_hyperparams,
    training_group,
    target_col,
    tune_hyperparameters,
    search_method,
    param_distributions,
    scoring_metric,
    best_features,
    n_best_features,
    remove_outliers,
    outlier_column,
    lower_quantile,
    upper_quantile,
    baseline_col,
    use_guardrail,
    guardrail_limit,
    use_weights,
    use_parallel,
    num_cpus
)
# Out:
# Number of cutoffs detected:  3
# CUDA is not available, using CPU with 8 available cores
# Running predictions sequentially
# ----------------------------------------------------------
# Processing cutoff: 2023-11-06
# ----------------------------------------------------------
# No feature selection: Using all features provided
# Training and predicting for cutoff: 2023-11-06, training group: 1
# Calculating guardrail for cutoff: 2023-11-06, training group: 1
# Training and predicting for cutoff: 2023-11-06, training group: 2
# Calculating guardrail for cutoff: 2023-11-06, training group: 2
# Training and predicting for cutoff: 2023-11-06, training group: 3
# Calculating guardrail for cutoff: 2023-11-06, training group: 3
# Training and predicting for cutoff: 2023-11-06, training group: 4
# Calculating guardrail for cutoff: 2023-11-06, training group: 4
# Training and predicting for cutoff: 2023-11-06, training group: 5
# Calculating guardrail for cutoff: 2023-11-06, training group: 5
# Training and predicting for cutoff: 2023-11-06, training group: 6
# Calculating guardrail for cutoff: 2023-11-06, training group: 6
# Training and predicting for cutoff: 2023-11-06, training group: 7
# Calculating guardrail for cutoff: 2023-11-06, training group: 7
# Training and predicting for cutoff: 2023-11-06, training group: 8
# Calculating guardrail for cutoff: 2023-11-06, training group: 8
# Training and predicting for cutoff: 2023-11-06, training group: 9
# Calculating guardrail for cutoff: 2023-11-06, training group: 9
# Training and predicting for cutoff: 2023-11-06, training group: 10
# Calculating guardrail for cutoff: 2023-11-06, training group: 10
# Training and predicting for cutoff: 2023-11-06, training group: 11
# Calculating guardrail for cutoff: 2023-11-06, training group: 11
# Training and predicting for cutoff: 2023-11-06, training group: 12
# Calculating guardrail for cutoff: 2023-11-06, training group: 12
# Training and predicting for cutoff: 2023-11-06, training group: 13
# Calculating guardrail for cutoff: 2023-11-06, training group: 13
# Training and predicting for cutoff: 2023-11-06, training group: 14
# Calculating guardrail for cutoff: 2023-11-06, training group: 14
# Training and predicting for cutoff: 2023-11-06, training group: 15
# Calculating guardrail for cutoff: 2023-11-06, training group: 15
# Dimensions of results dataframe: (537288, 68)
# Processing cutoff: 2023-12-04
# ----------------------------------------------------------
# No feature selection: Using all features provided
# Training and predicting for cutoff: 2023-12-04, training group: 1
# Calculating guardrail for cutoff: 2023-12-04, training group: 1
# Training and predicting for cutoff: 2023-12-04, training group: 2
# Calculating guardrail for cutoff: 2023-12-04, training group: 2
# Training and predicting for cutoff: 2023-12-04, training group: 3
# Calculating guardrail for cutoff: 2023-12-04, training group: 3
# Training and predicting for cutoff: 2023-12-04, training group: 4
# Calculating guardrail for cutoff: 2023-12-04, training group: 4
# Training and predicting for cutoff: 2023-12-04, training group: 5
# Calculating guardrail for cutoff: 2023-12-04, training group: 5
# Training and predicting for cutoff: 2023-12-04, training group: 6
# Calculating guardrail for cutoff: 2023-12-04, training group: 6
# Training and predicting for cutoff: 2023-12-04, training group: 7
# Calculating guardrail for cutoff: 2023-12-04, training group: 7
# Training and predicting for cutoff: 2023-12-04, training group: 8
# Calculating guardrail for cutoff: 2023-12-04, training group: 8
# Training and predicting for cutoff: 2023-12-04, training group: 9
# Calculating guardrail for cutoff: 2023-12-04, training group: 9
# Training and predicting for cutoff: 2023-12-04, training group: 10
# Calculating guardrail for cutoff: 2023-12-04, training group: 10
# Training and predicting for cutoff: 2023-12-04, training group: 11
# Calculating guardrail for cutoff: 2023-12-04, training group: 11
# Training and predicting for cutoff: 2023-12-04, training group: 12
# Calculating guardrail for cutoff: 2023-12-04, training group: 12
# Training and predicting for cutoff: 2023-12-04, training group: 13
# Calculating guardrail for cutoff: 2023-12-04, training group: 13
# Training and predicting for cutoff: 2023-12-04, training group: 14
# Calculating guardrail for cutoff: 2023-12-04, training group: 14
# Training and predicting for cutoff: 2023-12-04, training group: 15
# Calculating guardrail for cutoff: 2023-12-04, training group: 15
# Dimensions of results dataframe: (537288, 68)
# Processing cutoff: 2024-01-01
# ----------------------------------------------------------
# No feature selection: Using all features provided
# Training and predicting for cutoff: 2024-01-01, training group: 1
# Calculating guardrail for cutoff: 2024-01-01, training group: 1
# Training and predicting for cutoff: 2024-01-01, training group: 2
# Calculating guardrail for cutoff: 2024-01-01, training group: 2
# Training and predicting for cutoff: 2024-01-01, training group: 3
# Calculating guardrail for cutoff: 2024-01-01, training group: 3
# Training and predicting for cutoff: 2024-01-01, training group: 4
# Calculating guardrail for cutoff: 2024-01-01, training group: 4
# Training and predicting for cutoff: 2024-01-01, training group: 5
# Calculating guardrail for cutoff: 2024-01-01, training group: 5
# Training and predicting for cutoff: 2024-01-01, training group: 6
# Calculating guardrail for cutoff: 2024-01-01, training group: 6
# Training and predicting for cutoff: 2024-01-01, training group: 7
# Calculating guardrail for cutoff: 2024-01-01, training group: 7
# Training and predicting for cutoff: 2024-01-01, training group: 8
# Calculating guardrail for cutoff: 2024-01-01, training group: 8
# Training and predicting for cutoff: 2024-01-01, training group: 9
# Calculating guardrail for cutoff: 2024-01-01, training group: 9
# Training and predicting for cutoff: 2024-01-01, training group: 10
# Calculating guardrail for cutoff: 2024-01-01, training group: 10
# Training and predicting for cutoff: 2024-01-01, training group: 11
# Calculating guardrail for cutoff: 2024-01-01, training group: 11
# Training and predicting for cutoff: 2024-01-01, training group: 12
# Calculating guardrail for cutoff: 2024-01-01, training group: 12
# Training and predicting for cutoff: 2024-01-01, training group: 13
# Calculating guardrail for cutoff: 2024-01-01, training group: 13
# Training and predicting for cutoff: 2024-01-01, training group: 14
# Calculating guardrail for cutoff: 2024-01-01, training group: 14
# Training and predicting for cutoff: 2024-01-01, training group: 15
# Calculating guardrail for cutoff: 2024-01-01, training group: 15
# Dimensions of results dataframe: (575456, 68)
# ----------------------------------------------------------
# Predictions completed for all cutoffs and training groups
# CPU times: user 25min 21s, sys: 10.6 s, total: 25min 31s
# Wall time: 6min 59s

# %% [markdown]
# ## Optimization

# %%
# If hyperparameter tuning retrieve best combination
if tune_hyperparameters:

  # Retrieve and print the best hyperparameters for each cutoff
  best_hyperparams = predictor.get_best_hyperparams()
  print("Best Hyperparameters for each cutoff:")

  # Show
  for cutoff, params in best_hyperparams.items():
      print(f"Cutoff {cutoff}: {params}")

# %% [markdown]
# ## Guardrail

# %%
# If guardrail is activated
if use_guardrail:
  # Assuming 'df_with_preds' is the DataFrame
  group_cols = ['client', 'warehouse', 'product', 'cutoff']

  # Group by the specified columns and check for at least one True in each group
  guardrail_groups =  df_with_preds.groupby(group_cols)['guardrail'].any().reset_index()

  # Calculate the total number of groups
  total_groups = guardrail_groups.shape[0]

  # Count the number of groups where guardrail is True
  true_guardrail_groups_count = guardrail_groups['guardrail'].sum()

  # Calculate the percentage of groups with guardrail == True
  percentage_guardrail_true = (true_guardrail_groups_count / total_groups) * 100

  # Show
  print(f"Percentage of groups where guardrail is True: {percentage_guardrail_true:.2f}%")
# Out:
# Percentage of groups where guardrail is True: 0.00%

# %% [markdown]
# # Evaluate results

# %% [markdown]
# ## Feature importance

# %%
# Plot the average feature importance across all cutoffs
forecaster.plot_feature_importance()

# %% [markdown]
# ## Run evaluator

# %%
# Params
actuals_col = 'sales'
baseline_col = 'baseline_filled_sales_ma_13'
preds_col = ['prediction']

# Initialize the Evaluator class
evaluator = Evaluator(df_with_preds, actuals_col, baseline_col, preds_col)

# Create and print metric table
metric_table = evaluator.create_metric_table()

# Show
metric_table
# Out:
#                               RMSE    MAE    MAPE  WMAPE  Custom Metric
# baseline_filled_sales_ma_13  78.84  27.42  137.24  60.21          90.33
# prediction                   64.03  22.49  133.11  49.39          66.03

# %% [markdown]
# # Plot predictions

# %%
# Get the max cutoff
max_cutoff = df_with_preds['cutoff'].max()

# Filter the DataFrame where cutoff is equal to the max cutoff
df_filtered = df_with_preds[df_with_preds['cutoff'] == max_cutoff]

# Show
df_filtered.head()
# Out:
#          client  warehouse  product   id_column        date  sales  price  \
# 1074576       1         79    10446  1/79/10446  2020-07-06    0.0    NaN
# 1074577       1         79    13209  1/79/13209  2020-07-06    0.0    NaN
# 1074578       1         79    13731  1/79/13731  2020-07-06    0.0    NaN
# 1074579       1         79     2289   1/79/2289  2020-07-06    0.0    NaN
# 1074580       1         79     2839   1/79/2839  2020-07-06    0.0    NaN
#
#          filled_sales  filled_price      cutoff sample  feature_client  \
# 1074576           0.0           NaN  2024-01-01  train               0
# 1074577           0.0           NaN  2024-01-01  train               0
# 1074578           0.0           NaN  2024-01-01  train               0
# 1074579           0.0           NaN  2024-01-01  train               0
# 1074580           0.0           NaN  2024-01-01  train               0
#
#          feature_warehouse  feature_product  feature_id_column  \
# 1074576                 33               85                577
# 1074577                 33              575                620
# 1074578                 33              665                629
# 1074579                 33              925                648
# 1074580                 33             1038                655
#
#          feature_periods  feature_periods_expanding  feature_periods_sqrt  \
# 1074576              0.0                        0.0                   0.0
# 1074577              0.0                        0.0                   0.0
# 1074578              0.0                        0.0                   0.0
# 1074579              0.0                        0.0                   0.0
# 1074580              0.0                        0.0                   0.0
#
#          feature_year  feature_quarter  feature_month  feature_week  \
# 1074576          2020                3              7            28
# 1074577          2020                3              7            28
# 1074578          2020                3              7            28
# 1074579          2020                3              7            28
# 1074580          2020                3              7            28
#
#          feature_weeks_until_next_end_of_quarter  \
# 1074576                                       12
# 1074577                                       12
# 1074578                                       12
# 1074579                                       12
# 1074580                                       12
#
#          feature_weeks_until_end_of_year  \
# 1074576                               25
# 1074577                               25
# 1074578                               25
# 1074579                               25
# 1074580                               25
#
#          feature_months_until_next_end_of_quarter  \
# 1074576                                         2
# 1074577                                         2
# 1074578                                         2
# 1074579                                         2
# 1074580                                         2
#
#          feature_months_until_end_of_year  filled_sales_ma_4  \
# 1074576                                 5                0.0
# 1074577                                 5                0.0
# 1074578                                 5                0.0
# 1074579                                 5                0.0
# 1074580                                 5                0.0
#
#          filled_sales_ma_13  filled_price_ma_4  filled_price_ma_13  \
# 1074576                 0.0                NaN                 NaN
# 1074577                 0.0                NaN                 NaN
# 1074578                 0.0                NaN                 NaN
# 1074579                 0.0                NaN                 NaN
# 1074580                 0.0                NaN                 NaN
#
#          filled_sales_min_13  filled_sales_max_13  filled_price_min_13  \
# 1074576                  0.0                  0.0                  NaN
# 1074577                  0.0                  0.0                  NaN
# 1074578                  0.0                  0.0                  NaN
# 1074579                  0.0                  0.0                  NaN
# 1074580                  0.0                  0.0                  NaN
#
#          filled_price_max_13  feature_filled_sales_lag_13  \
# 1074576                  NaN                          NaN
# 1074577                  NaN                          NaN
# 1074578                  NaN                          NaN
# 1074579                  NaN                          NaN
# 1074580                  NaN                          NaN
#
#          feature_filled_sales_lag_52  feature_filled_price_lag_13  \
# 1074576                          NaN                          NaN
# 1074577                          NaN                          NaN
# 1074578                          NaN                          NaN
# 1074579                          NaN                          NaN
# 1074580                          NaN                          NaN
#
#          feature_filled_price_lag_52  feature_filled_sales_ma_4_lag_13  \
# 1074576                          NaN                               NaN
# 1074577                          NaN                               NaN
# 1074578                          NaN                               NaN
# 1074579                          NaN                               NaN
# 1074580                          NaN                               NaN
#
#          feature_filled_sales_ma_4_lag_52  feature_filled_price_ma_4_lag_13  \
# 1074576                               NaN                               NaN
# 1074577                               NaN                               NaN
# 1074578                               NaN                               NaN
# 1074579                               NaN                               NaN
# 1074580                               NaN                               NaN
#
#          feature_filled_price_ma_4_lag_52  feature_filled_sales_ma_13_lag_13  \
# 1074576                               NaN                                NaN
# 1074577                               NaN                                NaN
# 1074578                               NaN                                NaN
# 1074579                               NaN                                NaN
# 1074580                               NaN                                NaN
#
#          feature_filled_sales_ma_13_lag_52  feature_filled_price_ma_13_lag_13  \
# 1074576                                NaN                                NaN
# 1074577                                NaN                                NaN
# 1074578                                NaN                                NaN
# 1074579                                NaN                                NaN
# 1074580                                NaN                                NaN
#
#          feature_filled_price_ma_13_lag_52  \
# 1074576                                NaN
# 1074577                                NaN
# 1074578                                NaN
# 1074579                                NaN
# 1074580                                NaN
#
#          feature_filled_sales_min_13_lag_13  \
# 1074576                                 NaN
# 1074577                                 NaN
# 1074578                                 NaN
# 1074579                                 NaN
# 1074580                                 NaN
#
#          feature_filled_sales_min_13_lag_52  \
# 1074576                                 NaN
# 1074577                                 NaN
# 1074578                                 NaN
# 1074579                                 NaN
# 1074580                                 NaN
#
#          feature_filled_sales_max_13_lag_13  \
# 1074576                                 NaN
# 1074577                                 NaN
# 1074578                                 NaN
# 1074579                                 NaN
# 1074580                                 NaN
#
#          feature_filled_sales_max_13_lag_52  feature_filled_sales_cov  \
# 1074576                                 NaN                     13.49
# 1074577                                 NaN                     13.49
# 1074578                                 NaN                     13.49
# 1074579                                 NaN                      9.51
# 1074580                                 NaN                     13.49
#
#          feature_distinct_product_client  feature_distinct_product_warehouse  \
# 1074576                                1                                   1
# 1074577                                1                                   1
# 1074578                                1                                   1
# 1074579                                1                                   1
# 1074580                                1                                   1
#
#          feature_distinct_product_cutoff  feature_filled_sales_cluster  \
# 1074576                                3                             1
# 1074577                                3                             1
# 1074578                                3                             1
# 1074579                                3                             1
# 1074580                                3                             1
#
#          feature_filled_price_cluster  feature_periods_history_cluster  \
# 1074576                             1                                4
# 1074577                             1                                4
# 1074578                             1                                4
# 1074579                             1                                4
# 1074580                             1                                4
#
#          feature_intermittence_filled_sales_cluster  train_weight  \
# 1074576                                          14           0.0
# 1074577                                          14           0.0
# 1074578                                          15           0.0
# 1074579                                          13           0.0
# 1074580                                          15           0.0
#
#          feature_baseline_filled_sales_ma_13  \
# 1074576                                  0.0
# 1074577                                  0.0
# 1074578                                  0.0
# 1074579                                  0.0
# 1074580                                  0.0
#
#          feature_baseline_filled_price_ma_13  baseline_filled_sales_ma_13  \
# 1074576                                  NaN                          NaN
# 1074577                                  NaN                          NaN
# 1074578                                  NaN                          NaN
# 1074579                                  NaN                          NaN
# 1074580                                  NaN                          NaN
#
#          baseline_filled_price_ma_13  baseline_filled_price_lgbm  \
# 1074576                          NaN                         NaN
# 1074577                          NaN                         NaN
# 1074578                          NaN                         NaN
# 1074579                          NaN                         NaN
# 1074580                          NaN                         NaN
#
#          feature_baseline_filled_price_lgbm  training_group  guardrail  \
# 1074576                                 NaN               1      False
# 1074577                                 NaN               1      False
# 1074578                                 NaN               1      False
# 1074579                                 NaN               1      False
# 1074580                                 NaN               1      False
#
#          prediction
# 1074576         NaN
# 1074577         NaN
# 1074578         NaN
# 1074579         NaN
# 1074580         NaN

# %%
# Params
baseline_col = 'baseline_filled_sales_ma_13'
top_n_plots = 6

# %% [markdown]
# ## Plot by client

# %%
# Plot by client
process_and_plot(
    df_filtered,
    group_col='client',
    baseline_col=baseline_col,
    top_n=top_n_plots,
    title='Top Clients Sales vs Baseline vs Prediction'
)

# %% [markdown]
# ## Plot by warehouse

# %%
# Plot by warehouse
process_and_plot(
    df_filtered,
    group_col='warehouse',
    baseline_col=baseline_col,
    top_n=top_n_plots,
    title='Top Warehouses Sales vs Baseline vs Prediction'
)

# %% [markdown]
# ## Plot by Product

# %%
# Plot by product
process_and_plot(
    df_filtered,
    group_col='product',
    baseline_col=baseline_col,
    top_n=top_n_plots,
    title='Top Products Sales vs Baseline vs Prediction'
)

# %% [markdown]
# # Save output

# %%
# Create the filename with the phase appended
file_name = f'Data/df_lightgbm_preds.csv'

# Write the dataframe to the CSV file
df_with_preds.to_csv(file_name, index=False)

# %% [markdown]
# # Clean

# %%
# Garbage collection
gc.collect()
# Out:
# 69426
