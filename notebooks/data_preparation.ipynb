# %% [markdown]
# # Setup

# %%
# General libraries
import pandas as pd
import numpy as np

# Utilities
from pathlib import Path
import psutil
import gc
import os

# %%
# Warnings
import warnings

# Suppress general warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# Suppress the specific PerformanceWarning from pandas
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# Suppress SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# %% [markdown]
# # Directory

# %%
# Set the right directory
current_path = Path.cwd()
if current_path.name in ['notebooks','src']:
    os.chdir('..')
    print(f"Moved up from {current_path.name} to: {os.getcwd()}")
else:
    print(f"Already in project directory: {os.getcwd()}")
# Out:
# Moved up from notebooks to: /Users/ignasipascual/Documents/GitHub/Forecaster

# %% [markdown]
# # Assets

# %% [markdown]
# ## Import assets

# %%
# Import assets
from utils.data_preparation import DataPreparation
from utils.feature_engineering import FeatureEngineering
from utils.create_baselines import CreateBaselines
from utils.auxiliar import *

# %% [markdown]
# # Load data

# %%
# Raw URL of the CSV file
url = 'https://raw.githubusercontent.com/jordisc97/Kaggle_HackUPC/main/train_v_2_kaggle_23.csv'

# Load the CSV into a DataFrame
df_input = pd.read_csv(url)

# Show
df_input.head()
# Out:
#             id        date  year_week  product_number  reporterhq_id  \
# 0  202224-2961  2022-06-18     202224            2961             15
# 1  202225-2961  2022-06-25     202225            2961             15
# 2  202226-2961  2022-07-02     202226            2961             15
# 3  202227-2961  2022-07-09     202227            2961             15
# 4  202228-2961  2022-07-16     202228            2961             15
#
#   prod_category   specs  display_size segment  sales_units  inventory_units
# 0      Doraemon  186631          15.6  Gaming         52.0             88.0
# 1      Doraemon  186631          15.6  Gaming          6.0             88.0
# 2      Doraemon  186631          15.6  Gaming         60.0            138.0
# 3      Doraemon  186631          15.6  Gaming        158.0             65.0
# 4      Doraemon  186631          15.6  Gaming         23.0             30.0

# %% [markdown]
# ## Formatting

# %%
# Convert all column names to lowercase
df_input.columns = df_input.columns.str.lower()

# Date format
df_input['date'] = pd.to_datetime(df_input['date'])

# Convert each specified column to string
character_cols = ['reporterhq_id', 'product_number', 'prod_category', 'specs', 'display_size', 'segment']
for col in character_cols:
    df_input[col] = df_input[col].astype(str)

# Convert signal columns to numeric, coercing errors to NaN
signal_cols = ['sales_units', 'inventory_units']
for col in signal_cols:
    df_input[col] = pd.to_numeric(df_input[col], errors='coerce')

# Select the specified columns
df_input = df_input[['reporterhq_id', 'product_number', 'prod_category', 'specs', 'display_size', 'segment', 'date', 'sales_units', 'inventory_units']]

# Sort by 'id_column' and 'date' in ascending order
df_input = df_input.sort_values(by=['reporterhq_id', 'product_number', 'date'])

# Show
df_input.head()
# Out:
#     reporterhq_id product_number prod_category   specs display_size segment  \
# 913            12          10857      Doraemon  108304         15.6  Gaming
# 914            12          10857      Doraemon  108304         15.6  Gaming
# 915            12          10857      Doraemon  108304         15.6  Gaming
# 916            12          10857      Doraemon  108304         15.6  Gaming
# 917            12          10857      Doraemon  108304         15.6  Gaming
#
#           date  sales_units  inventory_units
# 913 2021-01-30          0.0             52.0
# 914 2021-02-06          8.0             48.0
# 915 2021-02-13         39.0             72.0
# 916 2021-02-20          0.0            138.0
# 917 2021-02-27         69.0             87.0

# %% [markdown]
# ## Statistics

# %%
# Print the number of rows and columns
print(f"Number of columns in df_input: {df_input.shape[1]}")
print(f"Number of rows in df_input: {df_input.shape[0]}")

# Print the number of distinct values for each specified column
print(f"Number of distinct reporterhq_id: {df_input['reporterhq_id'].nunique()}")
print(f"Number of distinct product_number: {df_input['product_number'].nunique()}")
# Out:
# Number of columns in df_input: 9
# Number of rows in df_input: 25139
# Number of distinct reporterhq_id: 20
# Number of distinct product_number: 233

# %%
# Calculate the percentage of NA values in the entire DataFrame
total_rows = len(df_input)
total_na = df_input.isna().sum().sum()
percent_na_total = (total_na / (total_rows * df_input.shape[1])) * 100
print(f"Percentage of NA values: {percent_na_total:.2f}%")
# Out:
# Percentage of NA values: 0.44%

# %% [markdown]
# # Data Preparation

# %%
# Parameters for data preparation
group_columns = ['reporterhq_id', 'product_number']
date_column = 'date'
target = 'inventory_units'
signal_columns = ['sales_units', 'inventory_units']
dp_window_size = 13
horizon = 13
freq = 'W-SAT'

# %%
# Init class
data_preparation = DataPreparation()

# %% [markdown]
# ## Smoothing

# %%
# Call the function
df_smoothed = data_preparation.smoothing(df_input, group_columns, date_column, signal_columns, dp_window_size)

# Show
df_smoothed.head()
# Out:
#     reporterhq_id product_number prod_category   specs display_size segment  \
# 913            12          10857      Doraemon  108304         15.6  Gaming
# 914            12          10857      Doraemon  108304         15.6  Gaming
# 915            12          10857      Doraemon  108304         15.6  Gaming
# 916            12          10857      Doraemon  108304         15.6  Gaming
# 917            12          10857      Doraemon  108304         15.6  Gaming
#
#           date  sales_units  inventory_units  filled_sales_units  \
# 913 2021-01-30          0.0             52.0                 0.0
# 914 2021-02-06          8.0             48.0                 8.0
# 915 2021-02-13         39.0             72.0                39.0
# 916 2021-02-20          0.0            138.0                 0.0
# 917 2021-02-27         69.0             87.0                69.0
#
#      filled_inventory_units
# 913                    52.0
# 914                    48.0
# 915                    72.0
# 916                   138.0
# 917                    87.0

# %% [markdown]
# ## Backtesting

# %%
# Parameters
n_cutoffs = 4

# Get the cutoff list
cutoff_list = data_preparation.get_first_dates_last_n_months(df_smoothed, date_column, n_cutoffs)

# Append the latest date to the list
latest_date = df_smoothed[date_column].max()
cutoff_list.append(latest_date)

# Convert list to DataFrame to use sort_values
cutoff_df = pd.DataFrame(cutoff_list, columns=[date_column])

# Drop duplicates and sort the DataFrame in ascending order
cutoff_df = cutoff_df.drop_duplicates().sort_values(by=date_column, ascending=True).reset_index(drop=True)

# Convert back to list
cutoff_list_sorted = cutoff_df[date_column].tolist()

# Show the sorted, distinct cutoff list
print(cutoff_list_sorted)
# Out:
# [Timestamp('2023-02-04 00:00:00'), Timestamp('2023-03-04 00:00:00'), Timestamp('2023-04-01 00:00:00'), Timestamp('2023-05-06 00:00:00')]

# %%
# Call the function
df_backtesting = data_preparation.create_backtesting_df(df_smoothed, date_column, cutoff_list_sorted)

# Show
df_backtesting.head()
# Out:
#   reporterhq_id product_number prod_category   specs display_size segment  \
# 0            12          10857      Doraemon  108304         15.6  Gaming
# 1            12          10857      Doraemon  108304         15.6  Gaming
# 2            12          10857      Doraemon  108304         15.6  Gaming
# 3            12          10857      Doraemon  108304         15.6  Gaming
# 4            12          10857      Doraemon  108304         15.6  Gaming
#
#         date  sales_units  inventory_units  filled_sales_units  \
# 0 2021-01-30          0.0             52.0                 0.0
# 1 2021-01-30          0.0             52.0                 0.0
# 2 2021-01-30          0.0             52.0                 0.0
# 3 2021-01-30          0.0             52.0                 0.0
# 4 2021-02-06          8.0             48.0                 8.0
#
#    filled_inventory_units     cutoff sample
# 0                    52.0 2023-02-04  train
# 1                    52.0 2023-03-04  train
# 2                    52.0 2023-04-01  train
# 3                    52.0 2023-05-06  train
# 4                    48.0 2023-02-04  train

# %%
# Print the number of rows and columns
print(f"Number of columns in df_backtesting: {df_backtesting.shape[1]}")
print(f"Number of rows in df_backtesting: {df_backtesting.shape[0]}")
# Out:
# Number of columns in df_backtesting: 13
# Number of rows in df_backtesting: 100556

# %% [markdown]
# ## Fill horizon

# %%
# Call the function
df_backtesting_with_horizon = data_preparation.add_horizon_last_cutoff(df_backtesting, group_columns, date_column, horizon, freq)

# Show
df_backtesting_with_horizon.head()
# Out:
#    reporterhq_id product_number prod_category   specs display_size segment  \
# 0             12          10857      Doraemon  108304         15.6  Gaming
# 3             12          10857      Doraemon  108304         15.6  Gaming
# 6             12          10857      Doraemon  108304         15.6  Gaming
# 9             12          10857      Doraemon  108304         15.6  Gaming
# 12            12          10857      Doraemon  108304         15.6  Gaming
#
#          date  sales_units  inventory_units  filled_sales_units  \
# 0  2021-01-30          0.0             52.0                 0.0
# 3  2021-02-06          8.0             48.0                 8.0
# 6  2021-02-13         39.0             72.0                39.0
# 9  2021-02-20          0.0            138.0                 0.0
# 12 2021-02-27         69.0             87.0                69.0
#
#     filled_inventory_units     cutoff sample
# 0                     52.0 2023-02-04  train
# 3                     48.0 2023-02-04  train
# 6                     72.0 2023-02-04  train
# 9                    138.0 2023-02-04  train
# 12                    87.0 2023-02-04  train

# %%
# Print the number of rows and columns
print(f"Number of columns in df_backtesting_with_horizon: {df_backtesting_with_horizon.shape[1]}")
print(f"Number of rows in df_backtesting_with_horizon: {df_backtesting_with_horizon.shape[0]}")
# Out:
# Number of columns in df_backtesting_with_horizon: 13
# Number of rows in df_backtesting_with_horizon: 107134

# %%
# Get memory details
memory = psutil.virtual_memory()

# Convert from bytes to GB
total_memory = memory.total / (1024 ** 3)
available_memory = memory.available / (1024 ** 3)
used_memory = memory.used / (1024 ** 3)

# Print memory details
print(f"Total Memory: {total_memory:.2f} GB")
print(f"Available Memory: {available_memory:.2f} GB")
print(f"Used Memory: {used_memory:.2f} GB")
# Out:
# Total Memory: 16.00 GB
# Available Memory: 5.36 GB
# Used Memory: 5.82 GB

# %% [markdown]
# # Feature Engineering

# %%
# Parameters for feature engineering
group_columns_fe = group_columns + ['cutoff']
date_column = 'date'
target = 'filled_inventory_units'
signal_columns_fe = ['filled_' + column for column in signal_columns]
lower_level_group = 'product_number'
fe_window_size = [4, 13]
lags = [13, 52]
fill_lags = True
freq = 'W'

# Number of clusters
n_groups = 15

# %%
# Init class
feature_engineering = FeatureEngineering()

# %% [markdown]
# ## Create encodings

# %%
# Find categorial columns
categorical_columns = df_backtesting_with_horizon.select_dtypes(include='object').columns.tolist()

# Exclude 'sample_column' from the list
categorical_columns = [col for col in categorical_columns if col != 'sample']

# Show
categorical_columns
# Out:
# ['reporterhq_id',
#  'product_number',
#  'prod_category',
#  'specs',
#  'display_size',
#  'segment']

# %%
# Apply the function
df_backtesting_with_categories = feature_engineering.create_encoded_features(df_backtesting_with_horizon, categorical_columns)

# Show
df_backtesting_with_categories.head()
# Out:
#    reporterhq_id product_number prod_category   specs display_size segment  \
# 0             12          10857      Doraemon  108304         15.6  Gaming
# 3             12          10857      Doraemon  108304         15.6  Gaming
# 6             12          10857      Doraemon  108304         15.6  Gaming
# 9             12          10857      Doraemon  108304         15.6  Gaming
# 12            12          10857      Doraemon  108304         15.6  Gaming
#
#          date  sales_units  inventory_units  filled_sales_units  \
# 0  2021-01-30          0.0             52.0                 0.0
# 3  2021-02-06          8.0             48.0                 8.0
# 6  2021-02-13         39.0             72.0                39.0
# 9  2021-02-20          0.0            138.0                 0.0
# 12 2021-02-27         69.0             87.0                69.0
#
#     filled_inventory_units     cutoff sample  feature_reporterhq_id  \
# 0                     52.0 2023-02-04  train                      0
# 3                     48.0 2023-02-04  train                      0
# 6                     72.0 2023-02-04  train                      0
# 9                    138.0 2023-02-04  train                      0
# 12                    87.0 2023-02-04  train                      0
#
#     feature_product_number  feature_prod_category  feature_specs  \
# 0                        7                      4              9
# 3                        7                      4              9
# 6                        7                      4              9
# 9                        7                      4              9
# 12                       7                      4              9
#
#     feature_display_size  feature_segment
# 0                      6                1
# 3                      6                1
# 6                      6                1
# 9                      6                1
# 12                     6                1

# %% [markdown]
# ## Period features

# %%
# Apply the function
df_backtesting_with_periods = feature_engineering.create_periods_feature(df_backtesting_with_categories, group_columns_fe, date_column, target)

# Show
df_backtesting_with_periods.head()
# Out:
#   reporterhq_id product_number prod_category   specs display_size segment  \
# 0            12          10857      Doraemon  108304         15.6  Gaming
# 1            12          10857      Doraemon  108304         15.6  Gaming
# 2            12          10857      Doraemon  108304         15.6  Gaming
# 3            12          10857      Doraemon  108304         15.6  Gaming
# 4            12          10857      Doraemon  108304         15.6  Gaming
#
#         date  sales_units  inventory_units  filled_sales_units  ...  sample  \
# 0 2021-01-30          0.0             52.0                 0.0  ...   train
# 1 2021-02-06          8.0             48.0                 8.0  ...   train
# 2 2021-02-13         39.0             72.0                39.0  ...   train
# 3 2021-02-20          0.0            138.0                 0.0  ...   train
# 4 2021-02-27         69.0             87.0                69.0  ...   train
#
#   feature_reporterhq_id feature_product_number  feature_prod_category  \
# 0                     0                      7                      4
# 1                     0                      7                      4
# 2                     0                      7                      4
# 3                     0                      7                      4
# 4                     0                      7                      4
#
#    feature_specs  feature_display_size  feature_segment  feature_periods  \
# 0              9                     6                1              1.0
# 1              9                     6                1              2.0
# 2              9                     6                1              3.0
# 3              9                     6                1              4.0
# 4              9                     6                1              5.0
#
#    feature_periods_expanding  feature_periods_sqrt
# 0                   1.000000              1.000000
# 1                   2.143547              1.414214
# 2                   3.348370              1.732051
# 3                   4.594793              2.000000
# 4                   5.873095              2.236068
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Calendar features

# %%
# Call the function
df_with_dates = feature_engineering.create_date_features(df_backtesting_with_periods, date_column, freq)

# Show
df_with_dates.head()
# Out:
#   reporterhq_id product_number prod_category   specs display_size segment  \
# 0            12          10857      Doraemon  108304         15.6  Gaming
# 1            12          10857      Doraemon  108304         15.6  Gaming
# 2            12          10857      Doraemon  108304         15.6  Gaming
# 3            12          10857      Doraemon  108304         15.6  Gaming
# 4            12          10857      Doraemon  108304         15.6  Gaming
#
#         date  sales_units  inventory_units  filled_sales_units  ...  \
# 0 2021-01-30          0.0             52.0                 0.0  ...
# 1 2021-02-06          8.0             48.0                 8.0  ...
# 2 2021-02-13         39.0             72.0                39.0  ...
# 3 2021-02-20          0.0            138.0                 0.0  ...
# 4 2021-02-27         69.0             87.0                69.0  ...
#
#    feature_cos_weekly_3 feature_days_until_end_of_month  \
# 0               0.62349                               1
# 1               0.62349                              22
# 2               0.62349                              15
# 3               0.62349                               8
# 4               0.62349                               1
#
#   feature_days_until_end_of_week  feature_days_until_end_of_quarter  \
# 0                              1                                 60
# 1                              1                                 53
# 2                              1                                 46
# 3                              1                                 39
# 4                              1                                 32
#
#    feature_days_until_end_of_year  feature_weeks_until_end_of_month  \
# 0                             335                          0.142857
# 1                             328                          3.142857
# 2                             321                          2.142857
# 3                             314                          1.142857
# 4                             307                          0.142857
#
#    feature_weeks_until_end_of_quarter  feature_weeks_until_end_of_year  \
# 0                            8.571429                        47.857143
# 1                            7.571429                        46.857143
# 2                            6.571429                        45.857143
# 3                            5.571429                        44.857143
# 4                            4.571429                        43.857143
#
#    feature_months_until_end_of_quarter  feature_months_until_end_of_year
# 0                                  2.0                              11.0
# 1                                  1.0                              10.0
# 2                                  1.0                              10.0
# 3                                  1.0                              10.0
# 4                                  1.0                              10.0
#
# [5 rows x 57 columns]

# %% [markdown]
# ## Moving average

# %%
# Call the function
df_with_ma = feature_engineering.create_ma_features(df_with_dates, group_columns_fe, signal_columns_fe, fe_window_size)

# Show
df_with_ma.head()
# Out:
#   reporterhq_id product_number prod_category   specs display_size segment  \
# 0            12          10857      Doraemon  108304         15.6  Gaming
# 1            12          10857      Doraemon  108304         15.6  Gaming
# 2            12          10857      Doraemon  108304         15.6  Gaming
# 3            12          10857      Doraemon  108304         15.6  Gaming
# 4            12          10857      Doraemon  108304         15.6  Gaming
#
#         date  sales_units  inventory_units  filled_sales_units  ...  \
# 0 2021-01-30          0.0             52.0                 0.0  ...
# 1 2021-02-06          8.0             48.0                 8.0  ...
# 2 2021-02-13         39.0             72.0                39.0  ...
# 3 2021-02-20          0.0            138.0                 0.0  ...
# 4 2021-02-27         69.0             87.0                69.0  ...
#
#    feature_days_until_end_of_year feature_weeks_until_end_of_month  \
# 0                             335                         0.142857
# 1                             328                         3.142857
# 2                             321                         2.142857
# 3                             314                         1.142857
# 4                             307                         0.142857
#
#   feature_weeks_until_end_of_quarter  feature_weeks_until_end_of_year  \
# 0                           8.571429                        47.857143
# 1                           7.571429                        46.857143
# 2                           6.571429                        45.857143
# 3                           5.571429                        44.857143
# 4                           4.571429                        43.857143
#
#    feature_months_until_end_of_quarter  feature_months_until_end_of_year  \
# 0                                  2.0                              11.0
# 1                                  1.0                              10.0
# 2                                  1.0                              10.0
# 3                                  1.0                              10.0
# 4                                  1.0                              10.0
#
#    filled_sales_units_ma_4  filled_sales_units_ma_13  \
# 0                 0.000000                  0.000000
# 1                 4.000000                  4.000000
# 2                15.666667                 15.666667
# 3                11.750000                 11.750000
# 4                29.000000                 23.200000
#
#    filled_inventory_units_ma_4  filled_inventory_units_ma_13
# 0                    52.000000                     52.000000
# 1                    50.000000                     50.000000
# 2                    57.333333                     57.333333
# 3                    77.500000                     77.500000
# 4                    86.250000                     79.400000
#
# [5 rows x 61 columns]

# %% [markdown]
# ## Moving stats

# %%
# Apply the function
df_with_min_max = feature_engineering.create_moving_stats(df_with_ma, group_columns_fe, signal_columns_fe, fe_window_size)

# Display the result
df_with_min_max.head()
# Out:
#   reporterhq_id product_number prod_category   specs display_size segment  \
# 0            12          10857      Doraemon  108304         15.6  Gaming
# 1            12          10857      Doraemon  108304         15.6  Gaming
# 2            12          10857      Doraemon  108304         15.6  Gaming
# 3            12          10857      Doraemon  108304         15.6  Gaming
# 4            12          10857      Doraemon  108304         15.6  Gaming
#
#         date  sales_units  inventory_units  filled_sales_units  ...  \
# 0 2021-01-30          0.0             52.0                 0.0  ...
# 1 2021-02-06          8.0             48.0                 8.0  ...
# 2 2021-02-13         39.0             72.0                39.0  ...
# 3 2021-02-20          0.0            138.0                 0.0  ...
# 4 2021-02-27         69.0             87.0                69.0  ...
#
#    filled_inventory_units_ma_4 filled_inventory_units_ma_13  \
# 0                    52.000000                    52.000000
# 1                    50.000000                    50.000000
# 2                    57.333333                    57.333333
# 3                    77.500000                    77.500000
# 4                    86.250000                    79.400000
#
#   filled_sales_units_min_4  filled_sales_units_max_4  \
# 0                      0.0                       0.0
# 1                      0.0                       8.0
# 2                      0.0                      39.0
# 3                      0.0                      39.0
# 4                      0.0                      69.0
#
#    filled_sales_units_min_13  filled_sales_units_max_13  \
# 0                        0.0                        0.0
# 1                        0.0                        8.0
# 2                        0.0                       39.0
# 3                        0.0                       39.0
# 4                        0.0                       69.0
#
#    filled_inventory_units_min_4  filled_inventory_units_max_4  \
# 0                          52.0                          52.0
# 1                          48.0                          52.0
# 2                          48.0                          72.0
# 3                          48.0                         138.0
# 4                          48.0                         138.0
#
#    filled_inventory_units_min_13  filled_inventory_units_max_13
# 0                           52.0                           52.0
# 1                           48.0                           52.0
# 2                           48.0                           72.0
# 3                           48.0                          138.0
# 4                           48.0                          138.0
#
# [5 rows x 69 columns]

# %% [markdown]
# ## Generate lags

# %%
# Parameters
lag_columns = [col for col in df_with_min_max.columns if col.startswith('filled_')]

# Create lag features in the DataFrame
df_with_lags = feature_engineering.create_lag_features(df_with_min_max, group_columns_fe, date_column, lag_columns, lags, fill_lags)

# Show
df_with_lags.head()
# Out:
#   reporterhq_id product_number prod_category   specs display_size segment  \
# 0            12          10857      Doraemon  108304         15.6  Gaming
# 1            12          10857      Doraemon  108304         15.6  Gaming
# 2            12          10857      Doraemon  108304         15.6  Gaming
# 3            12          10857      Doraemon  108304         15.6  Gaming
# 4            12          10857      Doraemon  108304         15.6  Gaming
#
#         date  sales_units  inventory_units  filled_sales_units  ...  \
# 0 2021-01-30          0.0             52.0                 0.0  ...
# 1 2021-02-06          8.0             48.0                 8.0  ...
# 2 2021-02-13         39.0             72.0                39.0  ...
# 3 2021-02-20          0.0            138.0                 0.0  ...
# 4 2021-02-27         69.0             87.0                69.0  ...
#
#    feature_filled_sales_units_max_13_lag_13  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   feature_filled_sales_units_max_13_lag_52  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   feature_filled_inventory_units_min_4_lag_13  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    feature_filled_inventory_units_min_4_lag_52  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    feature_filled_inventory_units_max_4_lag_13  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    feature_filled_inventory_units_max_4_lag_52  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    feature_filled_inventory_units_min_13_lag_13  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    feature_filled_inventory_units_min_13_lag_52  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    feature_filled_inventory_units_max_13_lag_13  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    feature_filled_inventory_units_max_13_lag_52
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
# [5 rows x 97 columns]

# %% [markdown]
# ## Get Cov ratio

# %%
# Call the function
df_with_cov = feature_engineering.create_cov(df_with_lags, group_columns_fe, target)

# Show
df_with_cov.head()
# Out:
#   reporterhq_id product_number prod_category   specs display_size segment  \
# 0            12          10857      Doraemon  108304         15.6  Gaming
# 1            12          10857      Doraemon  108304         15.6  Gaming
# 2            12          10857      Doraemon  108304         15.6  Gaming
# 3            12          10857      Doraemon  108304         15.6  Gaming
# 4            12          10857      Doraemon  108304         15.6  Gaming
#
#         date  sales_units  inventory_units  filled_sales_units  ...  \
# 0 2021-01-30          0.0             52.0                 0.0  ...
# 1 2021-02-06          8.0             48.0                 8.0  ...
# 2 2021-02-13         39.0             72.0                39.0  ...
# 3 2021-02-20          0.0            138.0                 0.0  ...
# 4 2021-02-27         69.0             87.0                69.0  ...
#
#    feature_filled_sales_units_max_13_lag_52  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   feature_filled_inventory_units_min_4_lag_13  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   feature_filled_inventory_units_min_4_lag_52  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    feature_filled_inventory_units_max_4_lag_13  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    feature_filled_inventory_units_max_4_lag_52  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    feature_filled_inventory_units_min_13_lag_13  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    feature_filled_inventory_units_min_13_lag_52  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    feature_filled_inventory_units_max_13_lag_13  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    feature_filled_inventory_units_max_13_lag_52  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    feature_filled_inventory_units_cov
# 0                            0.627141
# 1                            0.627141
# 2                            0.627141
# 3                            0.627141
# 4                            0.627141
#
# [5 rows x 98 columns]

# %% [markdown]
# ## ID combinations

# %%
# Call the function
df_with_combinations = feature_engineering.create_distinct_combinations(df_with_cov, group_columns_fe, lower_level_group)

# Show
df_with_combinations.head()
# Out:
#   reporterhq_id product_number prod_category   specs display_size segment  \
# 0            12          10857      Doraemon  108304         15.6  Gaming
# 1            12          10857      Doraemon  108304         15.6  Gaming
# 2            12          10857      Doraemon  108304         15.6  Gaming
# 3            12          10857      Doraemon  108304         15.6  Gaming
# 4            12          10857      Doraemon  108304         15.6  Gaming
#
#         date  sales_units  inventory_units  filled_sales_units  ...  \
# 0 2021-01-30          0.0             52.0                 0.0  ...
# 1 2021-02-06          8.0             48.0                 8.0  ...
# 2 2021-02-13         39.0             72.0                39.0  ...
# 3 2021-02-20          0.0            138.0                 0.0  ...
# 4 2021-02-27         69.0             87.0                69.0  ...
#
#    feature_filled_inventory_units_min_4_lag_52  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   feature_filled_inventory_units_max_4_lag_13  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   feature_filled_inventory_units_max_4_lag_52  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    feature_filled_inventory_units_min_13_lag_13  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    feature_filled_inventory_units_min_13_lag_52  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    feature_filled_inventory_units_max_13_lag_13  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    feature_filled_inventory_units_max_13_lag_52  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    feature_filled_inventory_units_cov  \
# 0                            0.627141
# 1                            0.627141
# 2                            0.627141
# 3                            0.627141
# 4                            0.627141
#
#    feature_distinct_product_number_reporterhq_id  \
# 0                                              2
# 1                                              2
# 2                                              2
# 3                                              2
# 4                                              2
#
#    feature_distinct_product_number_cutoff
# 0                                       4
# 1                                       4
# 2                                       4
# 3                                       4
# 4                                       4
#
# [5 rows x 100 columns]

# %% [markdown]
# ## Add clusters

# %%
# Call the function
df_with_clusters = feature_engineering.create_quantile_clusters(df_with_combinations, group_columns, signal_columns_fe, n_groups)

# Show
df_with_clusters.head()
# Out:
#   reporterhq_id product_number prod_category   specs display_size segment  \
# 0            12          10857      Doraemon  108304         15.6  Gaming
# 1            12          10857      Doraemon  108304         15.6  Gaming
# 2            12          10857      Doraemon  108304         15.6  Gaming
# 3            12          10857      Doraemon  108304         15.6  Gaming
# 4            12          10857      Doraemon  108304         15.6  Gaming
#
#         date  sales_units  inventory_units  filled_sales_units  ...  \
# 0 2021-01-30          0.0             52.0                 0.0  ...
# 1 2021-02-06          8.0             48.0                 8.0  ...
# 2 2021-02-13         39.0             72.0                39.0  ...
# 3 2021-02-20          0.0            138.0                 0.0  ...
# 4 2021-02-27         69.0             87.0                69.0  ...
#
#    feature_filled_inventory_units_max_4_lag_52  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   feature_filled_inventory_units_min_13_lag_13  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   feature_filled_inventory_units_min_13_lag_52  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    feature_filled_inventory_units_max_13_lag_13  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    feature_filled_inventory_units_max_13_lag_52  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    feature_filled_inventory_units_cov  \
# 0                            0.627141
# 1                            0.627141
# 2                            0.627141
# 3                            0.627141
# 4                            0.627141
#
#    feature_distinct_product_number_reporterhq_id  \
# 0                                              2
# 1                                              2
# 2                                              2
# 3                                              2
# 4                                              2
#
#    feature_distinct_product_number_cutoff  feature_filled_sales_units_cluster  \
# 0                                       4                                   5
# 1                                       4                                   5
# 2                                       4                                   5
# 3                                       4                                   5
# 4                                       4                                   5
#
#    feature_filled_inventory_units_cluster
# 0                                      10
# 1                                      10
# 2                                      10
# 3                                      10
# 4                                      10
#
# [5 rows x 102 columns]

# %%
# Call the function
df_with_clusters = feature_engineering.create_history_clusters(df_with_clusters, group_columns, signal_columns_fe, n_groups)

# Show
df_with_clusters.head()
# Out:
#   reporterhq_id product_number prod_category   specs display_size segment  \
# 0            12          10857      Doraemon  108304         15.6  Gaming
# 1            12          10857      Doraemon  108304         15.6  Gaming
# 2            12          10857      Doraemon  108304         15.6  Gaming
# 3            12          10857      Doraemon  108304         15.6  Gaming
# 4            12          10857      Doraemon  108304         15.6  Gaming
#
#         date  sales_units  inventory_units  filled_sales_units  ...  \
# 0 2021-01-30          0.0             52.0                 0.0  ...
# 1 2021-02-06          8.0             48.0                 8.0  ...
# 2 2021-02-13         39.0             72.0                39.0  ...
# 3 2021-02-20          0.0            138.0                 0.0  ...
# 4 2021-02-27         69.0             87.0                69.0  ...
#
#    feature_filled_inventory_units_min_13_lag_52  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   feature_filled_inventory_units_max_13_lag_13  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   feature_filled_inventory_units_max_13_lag_52  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    feature_filled_inventory_units_cov  \
# 0                            0.627141
# 1                            0.627141
# 2                            0.627141
# 3                            0.627141
# 4                            0.627141
#
#    feature_distinct_product_number_reporterhq_id  \
# 0                                              2
# 1                                              2
# 2                                              2
# 3                                              2
# 4                                              2
#
#    feature_distinct_product_number_cutoff  feature_filled_sales_units_cluster  \
# 0                                       4                                   5
# 1                                       4                                   5
# 2                                       4                                   5
# 3                                       4                                   5
# 4                                       4                                   5
#
#    feature_filled_inventory_units_cluster  \
# 0                                      10
# 1                                      10
# 2                                      10
# 3                                      10
# 4                                      10
#
#    feature_filled_sales_units_history_cluster  \
# 0                                           4
# 1                                           4
# 2                                           4
# 3                                           4
# 4                                           4
#
#    feature_filled_inventory_units_history_cluster
# 0                                              12
# 1                                              12
# 2                                              12
# 3                                              12
# 4                                              12
#
# [5 rows x 104 columns]

# %%
# Call the function
df_with_clusters = feature_engineering.create_intermittence_clusters(df_with_clusters, group_columns, signal_columns_fe, n_groups)

# Show
df_with_clusters.head()
# Out:
#   reporterhq_id product_number prod_category   specs display_size segment  \
# 0            12          10857      Doraemon  108304         15.6  Gaming
# 1            12          10857      Doraemon  108304         15.6  Gaming
# 2            12          10857      Doraemon  108304         15.6  Gaming
# 3            12          10857      Doraemon  108304         15.6  Gaming
# 4            12          10857      Doraemon  108304         15.6  Gaming
#
#         date  sales_units  inventory_units  filled_sales_units  ...  \
# 0 2021-01-30          0.0             52.0                 0.0  ...
# 1 2021-02-06          8.0             48.0                 8.0  ...
# 2 2021-02-13         39.0             72.0                39.0  ...
# 3 2021-02-20          0.0            138.0                 0.0  ...
# 4 2021-02-27         69.0             87.0                69.0  ...
#
#    feature_filled_inventory_units_max_13_lag_52  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   feature_filled_inventory_units_cov  \
# 0                           0.627141
# 1                           0.627141
# 2                           0.627141
# 3                           0.627141
# 4                           0.627141
#
#   feature_distinct_product_number_reporterhq_id  \
# 0                                             2
# 1                                             2
# 2                                             2
# 3                                             2
# 4                                             2
#
#    feature_distinct_product_number_cutoff  feature_filled_sales_units_cluster  \
# 0                                       4                                   5
# 1                                       4                                   5
# 2                                       4                                   5
# 3                                       4                                   5
# 4                                       4                                   5
#
#    feature_filled_inventory_units_cluster  \
# 0                                      10
# 1                                      10
# 2                                      10
# 3                                      10
# 4                                      10
#
#    feature_filled_sales_units_history_cluster  \
# 0                                           4
# 1                                           4
# 2                                           4
# 3                                           4
# 4                                           4
#
#    feature_filled_inventory_units_history_cluster  \
# 0                                              12
# 1                                              12
# 2                                              12
# 3                                              12
# 4                                              12
#
#    feature_intermittence_filled_sales_units_cluster  \
# 0                                                 9
# 1                                                 9
# 2                                                 9
# 3                                                 9
# 4                                                 9
#
#    feature_intermittence_filled_inventory_units_cluster
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
# [5 rows x 106 columns]

# %% [markdown]
# ## Train weights

# %%
# Call the function
df_with_train_weights = feature_engineering.create_train_weights(df_with_clusters, group_columns)

# Show
df_with_train_weights.head()
# Out:
#   reporterhq_id product_number prod_category   specs display_size segment  \
# 0            12          10857      Doraemon  108304         15.6  Gaming
# 1            12          10857      Doraemon  108304         15.6  Gaming
# 2            12          10857      Doraemon  108304         15.6  Gaming
# 3            12          10857      Doraemon  108304         15.6  Gaming
# 4            12          10857      Doraemon  108304         15.6  Gaming
#
#         date  sales_units  inventory_units  filled_sales_units  ...  \
# 0 2021-01-30          0.0             52.0                 0.0  ...
# 1 2021-02-06          8.0             48.0                 8.0  ...
# 2 2021-02-13         39.0             72.0                39.0  ...
# 3 2021-02-20          0.0            138.0                 0.0  ...
# 4 2021-02-27         69.0             87.0                69.0  ...
#
#    feature_filled_inventory_units_cov  \
# 0                            0.627141
# 1                            0.627141
# 2                            0.627141
# 3                            0.627141
# 4                            0.627141
#
#   feature_distinct_product_number_reporterhq_id  \
# 0                                             2
# 1                                             2
# 2                                             2
# 3                                             2
# 4                                             2
#
#   feature_distinct_product_number_cutoff  feature_filled_sales_units_cluster  \
# 0                                      4                                   5
# 1                                      4                                   5
# 2                                      4                                   5
# 3                                      4                                   5
# 4                                      4                                   5
#
#    feature_filled_inventory_units_cluster  \
# 0                                      10
# 1                                      10
# 2                                      10
# 3                                      10
# 4                                      10
#
#    feature_filled_sales_units_history_cluster  \
# 0                                           4
# 1                                           4
# 2                                           4
# 3                                           4
# 4                                           4
#
#    feature_filled_inventory_units_history_cluster  \
# 0                                              12
# 1                                              12
# 2                                              12
# 3                                              12
# 4                                              12
#
#    feature_intermittence_filled_sales_units_cluster  \
# 0                                                 9
# 1                                                 9
# 2                                                 9
# 3                                                 9
# 4                                                 9
#
#    feature_intermittence_filled_inventory_units_cluster  train_weight
# 0                                                  1         0.008547
# 1                                                  1         0.017094
# 2                                                  1         0.025641
# 3                                                  1         0.034188
# 4                                                  1         0.042735
#
# [5 rows x 107 columns]

# %% [markdown]
# ## Add Fcst Lag

# %%
# Call the function
df_with_fcst_lag = feature_engineering.create_fcst_lag_number(df_with_train_weights, group_columns, date_column)

# Show
df_with_fcst_lag.head()
# Out:
#     reporterhq_id product_number prod_category   specs display_size segment  \
# 0              12          10857      Doraemon  108304         15.6  Gaming
# 118            12          10857      Doraemon  108304         15.6  Gaming
# 236            12          10857      Doraemon  108304         15.6  Gaming
# 354            12          10857      Doraemon  108304         15.6  Gaming
# 1              12          10857      Doraemon  108304         15.6  Gaming
#
#           date  sales_units  inventory_units  filled_sales_units  ...  \
# 0   2021-01-30          0.0             52.0                 0.0  ...
# 118 2021-01-30          0.0             52.0                 0.0  ...
# 236 2021-01-30          0.0             52.0                 0.0  ...
# 354 2021-01-30          0.0             52.0                 0.0  ...
# 1   2021-02-06          8.0             48.0                 8.0  ...
#
#      feature_distinct_product_number_reporterhq_id  \
# 0                                                2
# 118                                              2
# 236                                              2
# 354                                              2
# 1                                                2
#
#     feature_distinct_product_number_cutoff feature_filled_sales_units_cluster  \
# 0                                        4                                  5
# 118                                      4                                  5
# 236                                      4                                  5
# 354                                      4                                  5
# 1                                        4                                  5
#
#      feature_filled_inventory_units_cluster  \
# 0                                        10
# 118                                      10
# 236                                      10
# 354                                      10
# 1                                        10
#
#      feature_filled_sales_units_history_cluster  \
# 0                                             4
# 118                                           4
# 236                                           4
# 354                                           4
# 1                                             4
#
#      feature_filled_inventory_units_history_cluster  \
# 0                                                12
# 118                                              12
# 236                                              12
# 354                                              12
# 1                                                12
#
#      feature_intermittence_filled_sales_units_cluster  \
# 0                                                   9
# 118                                                 9
# 236                                                 9
# 354                                                 9
# 1                                                   9
#
#      feature_intermittence_filled_inventory_units_cluster  train_weight  \
# 0                                                    1         0.008547
# 118                                                  1         0.008547
# 236                                                  1         0.008547
# 354                                                  1         0.008547
# 1                                                    1         0.017094
#
#      fcst_lag
# 0           0
# 118         0
# 236         0
# 354         0
# 1           0
#
# [5 rows x 108 columns]

# %% [markdown]
# # Create baselines

# %%
# Parameters for baseline creation
group_columns_cb = group_columns + ['cutoff']
date_column = 'date'

# MA Baseline parameters
signal_columns = ['filled_sales_units', 'filled_inventory_units']
bs_window_size = 13

# %%
# Prepare class
create_baselines = CreateBaselines()

# %% [markdown]
# ## MA Baseline

# %%
# Call the function
df_with_ma_baseline = create_baselines.create_ma_baseline(df_with_fcst_lag, group_columns_cb, date_column, signal_columns, bs_window_size)

# Show
df_with_ma_baseline.head()
# Out:
#   reporterhq_id product_number prod_category   specs display_size segment  \
# 0            12          10857      Doraemon  108304         15.6  Gaming
# 1            12          10857      Doraemon  108304         15.6  Gaming
# 2            12          10857      Doraemon  108304         15.6  Gaming
# 3            12          10857      Doraemon  108304         15.6  Gaming
# 4            12          10857      Doraemon  108304         15.6  Gaming
#
#         date  sales_units  inventory_units  filled_sales_units  ...  \
# 0 2021-01-30          0.0             52.0                 0.0  ...
# 1 2021-02-06          8.0             48.0                 8.0  ...
# 2 2021-02-13         39.0             72.0                39.0  ...
# 3 2021-02-20          0.0            138.0                 0.0  ...
# 4 2021-02-27         69.0             87.0                69.0  ...
#
#    feature_filled_sales_units_history_cluster  \
# 0                                           4
# 1                                           4
# 2                                           4
# 3                                           4
# 4                                           4
#
#   feature_filled_inventory_units_history_cluster  \
# 0                                             12
# 1                                             12
# 2                                             12
# 3                                             12
# 4                                             12
#
#   feature_intermittence_filled_sales_units_cluster  \
# 0                                                9
# 1                                                9
# 2                                                9
# 3                                                9
# 4                                                9
#
#    feature_intermittence_filled_inventory_units_cluster  train_weight  \
# 0                                                  1         0.008547
# 1                                                  1         0.017094
# 2                                                  1         0.025641
# 3                                                  1         0.034188
# 4                                                  1         0.042735
#
#    fcst_lag  feature_baseline_filled_sales_units_ma_13_ma_13  \
# 0         0                                         0.000000
# 1         0                                         2.000000
# 2         0                                         6.555556
# 3         0                                         7.854167
# 4         0                                        10.923333
#
#    feature_baseline_filled_inventory_units_ma_13_ma_13  \
# 0                                          52.000000
# 1                                          51.000000
# 2                                          53.111111
# 3                                          59.208333
# 4                                          63.246667
#
#    baseline_filled_sales_units_ma_13_ma_13  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    baseline_filled_inventory_units_ma_13_ma_13
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
# [5 rows x 112 columns]

# %% [markdown]
# # Save output

# %%
# Check if any column is completely filled with NaN values
na_columns = df_with_ma_baseline.columns[df_with_ma_baseline.isna().all()].tolist()

# Show
print("Columns full of NaN values:", na_columns)
# Out:
# Columns full of NaN values: []

# %%
# Round all float columns to 2 decimal places
float_cols = df_with_ma_baseline.select_dtypes(include=['float']).columns
df_with_ma_baseline[float_cols] = df_with_ma_baseline[float_cols].round(2)

# Show
df_with_ma_baseline.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107134 entries, 0 to 107133
# Columns: 112 entries, reporterhq_id to baseline_filled_inventory_units_ma_13_ma_13
# dtypes: datetime64[ns](2), float64(78), int32(5), int64(20), object(7)
# memory usage: 89.5+ MB

# %%
# Get memory details
memory = psutil.virtual_memory()

# Convert from bytes to GB
total_memory = memory.total / (1024 ** 3)
available_memory = memory.available / (1024 ** 3)
used_memory = memory.used / (1024 ** 3)

# Print memory details
print(f"Total Memory: {total_memory:.2f} GB")
print(f"Available Memory: {available_memory:.2f} GB")
print(f"Used Memory: {used_memory:.2f} GB")
# Out:
# Total Memory: 16.00 GB
# Available Memory: 4.88 GB
# Used Memory: 6.16 GB

# %%
# Create the filename with the phase appended
file_name = f'data/df_backtesting.csv'

# Write the dataframe to the CSV file
df_with_ma_baseline.to_csv(file_name, index=False)

# %%
# Get memory details
memory = psutil.virtual_memory()

# Convert from bytes to GB
total_memory = memory.total / (1024 ** 3)
available_memory = memory.available / (1024 ** 3)
used_memory = memory.used / (1024 ** 3)

# Print memory details
print(f"Total Memory: {total_memory:.2f} GB")
print(f"Available Memory: {available_memory:.2f} GB")
print(f"Used Memory: {used_memory:.2f} GB")
# Out:
# Total Memory: 16.00 GB
# Available Memory: 4.88 GB
# Used Memory: 6.15 GB

# %% [markdown]
# # Clean

# %%
# Garbage collection
gc.collect()
# Out:
# 0
